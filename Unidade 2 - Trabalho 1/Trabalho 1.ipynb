# %% [markdown]
# # Unidade 2 - Trabalho 1
#
# ## Criar gráficos Z-Score com a probabilidade da área em verde similar a figura ao lado e relacionado com as notas da primeira, segunda, terceira unidades e média final das disciplinas:
# ### ○ FMC I, FMC II e Probabilidade do BTI
# ### ○ Para testes, escolha as notas 5.0, 7.0 e 9.0
# ### ○ Utilizar os dados disponibilizados em "dados.ufrn.br"

# %%
#Importando o componentes-curriculares-presenciais.csv

import pandas as pd

turmas = pd.read_csv("componentes-curriculares-presenciais.csv", sep = ";")

#Filtrando o .csv para apenas as turmas do imd
turmas_imd = turmas[turmas['codigo'].str.contains("IMD")]
turmas_imd_id = turmas_imd['id_componente'].unique()
print(len(turmas_imd_id))
turmas_imd.head(2)
# Out:
# 374
#        id_componente tipo_componente   codigo nivel                  nome  \
# 17834          51954          MODULO  IMD0001     L  INOVAÇÃO TECNOLÓGICA
# 18093          52247          MODULO  IMD0002     L  INOVAÇÃO TECNOLÓGICA
#
#                unidade_responsavel  ch_teorico  ch_pratico  ch_estagio  \
# 17834  INSTITUTO METROPOLE DIGITAL          15           0           0
# 18093  INSTITUTO METROPOLE DIGITAL          30           0           0
#
#        ch_total                  ...                   \
# 17834        15                  ...
# 18093        30                  ...
#
#                                                   ementa  bibliografia  \
# 17834                                                ...           NaN
# 18093  Conceito de inovação. Tipos de inovação. Relaç...           NaN
#
#        objetivos conteudo  competencias_habilidades referencias ano_programa  \
# 17834        NaN      NaN                       NaN         NaN          NaN
# ...

# %% [markdown]
# ### O id_componente do componentes-curriculares-presenciais.csv é igual ao id_componente_curricular dos turmas-201X.Y.csv

# %%
#Ler os arquivos das turmas desde 2013.1

#PEGAR PRA FMC I, FMC II E PROBABILIDADE
turmas2017_1 = pd.read_csv("turmas-2017.1.csv", sep = ";")
turmas2016_2 = pd.read_csv("turmas-2016.2.csv", sep = ";")
turmas2016_1 = pd.read_csv("turmas-2016.1.csv", sep = ";")
turmas2015_2 = pd.read_csv("turmas-2015.2.csv", sep = ";")
turmas2015_1 = pd.read_csv("turmas-2015.1.csv", sep = ";")
turmas2014_2 = pd.read_csv("turmas-2014.2.csv", sep = ";")
turmas2014_1 = pd.read_csv("turmas-2014.1.csv", sep = ";")

#PEGAR PRA PROBABILIDADE
turmas2013_2 = pd.read_csv("turmas-2013.2.csv", sep = ";")
turmas2013_1 = pd.read_csv("turmas-2013.1.csv", sep = ";")

turmas2013_1.head()
# Out:
#    id_turma codigo_turma  id_docente_interno  id_docente_externo observacao  \
# 0   1196178           01           3028953.0                 NaN        NaN
# 1   1196210          T01                 NaN           2264968.0        NaN
# 2   1196211          T02                 NaN          92721509.0        NaN
# 3   1196212          T03                 NaN          98388697.0        NaN
# 4   1196213          T04                 NaN          98388762.0        NaN
#
#    id_componente_curricular nivel_ensino campus_turma  \
# 0                     50280   LATO SENSU          NaN
# 1                     52540      TÉCNICO          NaN
# 2                     52540      TÉCNICO          NaN
# 3                     52540      TÉCNICO          NaN
# 4                     52540      TÉCNICO          NaN
#
#                          local   ano     ...         tipo distancia  \
# 0  Campus Universitário - Svf5  2013     ...      REGULAR         f
# ...

# %%
turmas2013_1 = turmas2013_1[turmas2013_1['id_componente_curricular']==turmas_imd_id[8]]
turmas2013_1.head()
# Out:
# Empty DataFrame
# Columns: [id_turma, codigo_turma, id_docente_interno, id_docente_externo, observacao, id_componente_curricular, nivel_ensino, campus_turma, local, ano, periodo, data_inicio, data_fim, descricao_horario, total_solicitacoes, capacidade_aluno, tipo, distancia, data_consolidacao, agrupadora, id_turma_agrupadora, qtd_aulas_lancadas, situacao_turma, convenio, modalidade_participantes, Unnamed: 25]
# Index: []
#
# [0 rows x 26 columns]

# %%
turmas_imd_2017_1_cons = turmas2017_1[turmas2017_1['situacao_turma'].str.contains("CONSOLIDADA")]
turmas_imd_2017_1_cons = turmas_imd_2017_1_cons[~turmas_imd_2017_1_cons.duplicated('id_turma')]

turmas_imd_2016_2_cons = turmas2016_2[turmas2016_2['situacao_turma'].str.contains("CONSOLIDADA")]
turmas_imd_2016_2_cons = turmas_imd_2016_2_cons[~turmas_imd_2016_2_cons.duplicated('id_turma')]

turmas_imd_2016_1_cons = turmas2016_1[turmas2016_1['situacao_turma'].str.contains("CONSOLIDADA")]
turmas_imd_2016_1_cons = turmas_imd_2016_1_cons[~turmas_imd_2016_1_cons.duplicated('id_turma')]

turmas_imd_2015_2_cons = turmas2015_2[turmas2015_2['situacao_turma'].str.contains("CONSOLIDADA")]
turmas_imd_2015_2_cons = turmas_imd_2015_2_cons[~turmas_imd_2015_2_cons.duplicated('id_turma')]

turmas_imd_2015_1_cons = turmas2015_1[turmas2015_1['situacao_turma'].str.contains("CONSOLIDADA")]
turmas_imd_2015_1_cons = turmas_imd_2015_1_cons[~turmas_imd_2015_1_cons.duplicated('id_turma')]

#turmas_imd_2014_2_cons = turmas2014_2[turmas2014_2['situacao_turma'].str.contains("CONSOLIDADA")]
#turmas_imd_2014_2_cons = turmas_imd_2014_2_cons[~turmas_imd_2014_2_cons.duplicated('id_turma')]

turmas_imd_2014_1_cons = turmas2014_1[turmas2014_1['situacao_turma'].str.contains("CONSOLIDADA")]
turmas_imd_2014_1_cons = turmas_imd_2014_1_cons[~turmas_imd_2014_1_cons.duplicated('id_turma')]

turmas_imd_2013_2_cons = turmas2013_2[turmas2013_2['situacao_turma'].str.contains("CONSOLIDADA")]
turmas_imd_2013_2_cons = turmas_imd_2013_2_cons[~turmas_imd_2013_2_cons.duplicated('id_turma')]

turmas_imd_2013_1_cons = turmas2013_1[turmas2013_1['situacao_turma'].str.contains("CONSOLIDADA")]
turmas_imd_2013_1_cons = turmas_imd_2013_1_cons[~turmas_imd_2013_1_cons.duplicated('id_turma')]

# %%
turmas2014_2.head()
# Out:
#   id_turma codigo_turma id_docente_interno  id_docente_externo observacao  \
# 0  1207250           01            5755580                 NaN        NaN
# 1  1213722           01              23859                 NaN        NaN
# 2  1217095           01            3029296                 NaN        NaN
# 3  1217097           01            5753571                 NaN        NaN
# 4  1217097           01            5753068                 NaN        NaN
#
#    id_componente_curricular nivel_ensino campus_turma  \
# 0                   53648.0   LATO SENSU          NaN
# 1                   54158.0   LATO SENSU          NaN
# 2                   52919.0   LATO SENSU          NaN
# 3                   53074.0   LATO SENSU          NaN
# 4                   53074.0   LATO SENSU          NaN
#
#                                  local   ano     ...         tipo distancia  \
# 0                   Setor II - Sala C4  2014     ...      REGULAR         f
# ...

# %%
turmas2017_1_fmcI = turmas_imd_cons[turmas_imd_cons['codigo'].str.contains("IMD0033")]
id_probabilidade = list(probabilidade['id_turma'])

matricula_comp_id_turma1 = matricula_comp[matricula_comp['id_turma'] == id_probabilidade[0]]
matricula_comp_id_turma2 = matricula_comp[matricula_comp['id_turma'] == id_probabilidade[1]]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\paulalsouza\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'codigo'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
turmas2017_1 = pd.read_csv("turmas-2017.1.csv", sep = ";")
turmas_imd = turmas[turmas['codigo'].str.contains("IMD")]
turmas_imd_cons = turmas_imd[turmas_imd['situacao_turma'].str.contains("CONSOLIDADA")]
turmas_imd_cons = turmas_imd_cons[~turmas_imd_cons.duplicated('id_turma')]
print('1. Foram consolidadas ' + str(len(turmas_imd_cons)) + ' turmas:')
print(turmas_imd_cons['codigo'].unique())

# %%
#print(turmas_imd_cons)
fmc = turmas_imd_cons[turmas_imd_cons['nome_ascii'].str.contains("FUNDAMENTOS MATEMATICOS DA COMPUTACAO I")]
print(fmc)
# Out:
#       id_turma   codigo                                nome_ascii  \
# 5570  57597592  IMD0028   FUNDAMENTOS MATEMATICOS DA COMPUTACAO I
# 5983  57597922  IMD0038  FUNDAMENTOS MATEMATICOS DA COMPUTACAO II
# 5988  57597928  IMD0038  FUNDAMENTOS MATEMATICOS DA COMPUTACAO II
# 9870  57600129  IMD0028   FUNDAMENTOS MATEMATICOS DA COMPUTACAO I
# 9871  57600130  IMD0028   FUNDAMENTOS MATEMATICOS DA COMPUTACAO I
#
#                        docente_interno docente_externo nivel_ensino   ano  \
# 5570  014ec19f7505af82a85fd57100dc4807             NaN    GRADUAÇÃO  2017
# 5983  5258ff44921100de32b56af4b06edf2d             NaN    GRADUAÇÃO  2017
# 5988  5258ff44921100de32b56af4b06edf2d             NaN    GRADUAÇÃO  2017
# 9870  6040a6c8488f5274cd2898440646afc0             NaN    GRADUAÇÃO  2017
# 9871  117eb3d847f2ecfebf4034714b820ffa             NaN    GRADUAÇÃO  2017
#
#       periodo  capacidade_aluno        local     ...      distancia tipo  \
# ...

# %%
matricula_comp = pd.read_csv("matricula-componente-20171.csv", ";")
matricula_comp
# Out:
#         id_turma                       id_discente     id_curso  unidade  \
# 0       57597218  a7d1d2db85b7bcf16c5e77ce8bfdc7b3    2000057.0      3.0
# 1       57597218  a7d1d2db85b7bcf16c5e77ce8bfdc7b3    2000057.0      2.0
# 2       57597218  a7d1d2db85b7bcf16c5e77ce8bfdc7b3    2000057.0      1.0
# 3       57597218  4c3df36bd27088da2fc58954dd33abc0    2000057.0      3.0
# 4       57597218  4c3df36bd27088da2fc58954dd33abc0    2000057.0      2.0
# 5       57597218  4c3df36bd27088da2fc58954dd33abc0    2000057.0      1.0
# 6       57597218  8cb4d7851ad0e194239d6ca9afa97f8f    2000057.0      2.0
# 7       57597218  8cb4d7851ad0e194239d6ca9afa97f8f    2000057.0      1.0
# 8       57597218  8cb4d7851ad0e194239d6ca9afa97f8f    2000057.0      3.0
# 9       57597218  da8caf19052dc7c5b8b7c6417c586cd4    2000057.0      3.0
# 10      57597218  da8caf19052dc7c5b8b7c6417c586cd4    2000057.0      2.0
# 11      57597218  da8caf19052dc7c5b8b7c6417c586cd4    2000057.0      1.0
# ...

# %%
probabilidade = turmas_imd_cons[turmas_imd_cons['codigo'].str.contains("IMD0033")]
fmcI = turmas_imd_cons[turmas_imd_cons['codigo'].str.contains("IMD0028")]
fmcII = turmas_imd_cons[turmas_imd_cons['codigo'].str.contains("IMD0038")]
